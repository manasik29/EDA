# %% [markdown]
# <a href="https://colab.research.google.com/github/manasik29/EDA1/blob/main/EDA1_pandas_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_profiling==2.7.1

# %%
pip install MarkupSafe==2.0.1

# %%
# !pip install https://github.com/ydataai/pandas-profiling/archive/master.zip

# %%
import pandas as pd
data = pd.read_csv('/content/data_clean.csv')

# %%
import pandas_profiling as pp

# %%
EDA_report= pp.ProfileReport(data)
EDA_report.to_file(output_file='report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
